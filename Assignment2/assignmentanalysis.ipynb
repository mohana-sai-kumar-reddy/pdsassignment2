# %%
import pandas as pd

# %%
raw_carsreused=pd.read_csv('/content/train.csv')

# %%
raw_carsreused
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 1              2                      Honda Jazz V     Chennai  2011
# 2              3                 Maruti Ertiga VDI     Chennai  2012
# 3              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 4              6            Nissan Micra Diesel XV      Jaipur  2013
# ...          ...                               ...         ...   ...
# 5842        6014                  Maruti Swift VDI       Delhi  2014
# 5843        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 5844        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 5845        6017                Maruti Wagon R VXI     Kolkata  2013
# 5846        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
raw_carsreused.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats        Price
# count  5847.000000  5847.000000       5.847000e+03  5809.000000  5847.000000
# mean   3013.181461  2013.448435       5.841013e+04     5.286452     9.653742
# std    1736.398890     3.194949       9.237971e+04     0.806668    11.275966
# min       1.000000  1998.000000       1.710000e+02     2.000000     0.440000
# 25%    1509.500000  2012.000000       3.346750e+04     5.000000     3.550000
# 50%    3015.000000  2014.000000       5.257600e+04     5.000000     5.750000
# 75%    4517.500000  2016.000000       7.249050e+04     5.000000    10.250000
# max    6018.000000  2019.000000       6.500000e+06    10.000000   160.000000

# %%
raw_carsreused.isna()
# Out:
#       Unnamed: 0   Name  Location   Year  Kilometers_Driven  Fuel_Type  \
# 0          False  False     False  False              False      False
# 1          False  False     False  False              False      False
# 2          False  False     False  False              False      False
# 3          False  False     False  False              False      False
# 4          False  False     False  False              False      False
# ...          ...    ...       ...    ...                ...        ...
# 5842       False  False     False  False              False      False
# 5843       False  False     False  False              False      False
# 5844       False  False     False  False              False      False
# 5845       False  False     False  False              False      False
# 5846       False  False     False  False              False      False
#
#       Transmission  Owner_Type  Mileage  Engine  Power  Seats  New_Price  \
# ...

# %%
clean_carsreused=raw_carsreused.dropna(inplace=False)
clean_carsreused
# Out:
#       Unnamed: 0                               Name Location  Year  \
# 1              2                       Honda Jazz V  Chennai  2011
# 5              7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016
# 8             10                   Maruti Ciaz Zeta    Kochi  2018
# 13            15        Mitsubishi Pajero Sport 4X4    Delhi  2014
# 18            20                  BMW 3 Series 320d    Kochi  2014
# ...          ...                                ...      ...   ...
# 5827        5999              Tata Bolt Revotron XT  Chennai  2016
# 5830        6002      Volkswagen Vento 1.6 Highline   Mumbai  2011
# 5833        6005           Maruti Vitara Brezza VDi     Pune  2016
# 5838        6010               Honda Brio 1.2 VX MT    Delhi  2013
# 5842        6014                   Maruti Swift VDI    Delhi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 1                 46000    Petrol       Manual      First    13 km/kg
# ...

# %%
clean_carsreused.to_csv('/content/clean_carsreused.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
data_of_cars=pd.read_csv('/content/clean_carsreused.csv')

# %%
data_of_cars
# Out:
#      Unnamed: 0.1  Unnamed: 0                               Name Location  \
# 0               1           2                       Honda Jazz V  Chennai
# 1               5           7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai
# 2               8          10                   Maruti Ciaz Zeta    Kochi
# 3              13          15        Mitsubishi Pajero Sport 4X4    Delhi
# 4              18          20                  BMW 3 Series 320d    Kochi
# ..            ...         ...                                ...      ...
# 809          5827        5999              Tata Bolt Revotron XT  Chennai
# 810          5830        6002      Volkswagen Vento 1.6 Highline   Mumbai
# 811          5833        6005           Maruti Vitara Brezza VDi     Pune
# 812          5838        6010               Honda Brio 1.2 VX MT    Delhi
# 813          5842        6014                   Maruti Swift VDI    Delhi
#
#      Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
data_of_cars_copy = data_of_cars.copy()
data_of_cars_copy['Mileage'] = data_of_cars_copy['Mileage'].astype(str).str.replace('kmpl', '').str.replace('km/kg', '').astype(float)
data_of_cars_copy['Engine'] = data_of_cars_copy['Engine'].astype(str).str.replace('CC', '').astype(float)
data_of_cars_copy['Power'] = data_of_cars_copy['Power'].astype(str).str.replace('bhp', '').astype(float)
data_of_cars_copy['New_Price'] = data_of_cars_copy['New_Price'].astype(str).str.replace('Lakh', '')
data_of_cars_copy['New_Price'] = data_of_cars_copy['New_Price'].str.replace('Cr', '').apply(lambda x: float(x) * 100 if 'Cr' in x else float(x))

# %%
data_of_cars_copy
# Out:
#      Unnamed: 0.1  Unnamed: 0                               Name Location  \
# 0               1           2                       Honda Jazz V  Chennai
# 1               5           7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai
# 2               8          10                   Maruti Ciaz Zeta    Kochi
# 3              13          15        Mitsubishi Pajero Sport 4X4    Delhi
# 4              18          20                  BMW 3 Series 320d    Kochi
# ..            ...         ...                                ...      ...
# 809          5827        5999              Tata Bolt Revotron XT  Chennai
# 810          5830        6002      Volkswagen Vento 1.6 Highline   Mumbai
# 811          5833        6005           Maruti Vitara Brezza VDi     Pune
# 812          5838        6010               Honda Brio 1.2 VX MT    Delhi
# 813          5842        6014                   Maruti Swift VDI    Delhi
#
#      Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# ...

# %%
data_of_cars
# Out:
#      Unnamed: 0.1  Unnamed: 0                               Name Location  \
# 0               1           2                       Honda Jazz V  Chennai
# 1               5           7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai
# 2               8          10                   Maruti Ciaz Zeta    Kochi
# 3              13          15        Mitsubishi Pajero Sport 4X4    Delhi
# 4              18          20                  BMW 3 Series 320d    Kochi
# ..            ...         ...                                ...      ...
# 809          5827        5999              Tata Bolt Revotron XT  Chennai
# 810          5830        6002      Volkswagen Vento 1.6 Highline   Mumbai
# 811          5833        6005           Maruti Vitara Brezza VDi     Pune
# 812          5838        6010               Honda Brio 1.2 VX MT    Delhi
# 813          5842        6014                   Maruti Swift VDI    Delhi
#
#      Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
data_of_cars = pd.get_dummies(data_of_cars_copy, columns=['Fuel_Type', 'Transmission'], drop_first=True)

# %%
current_year = datetime.now().year
data_of_cars['Current_age'] = current_year - data_of_cars['Year']
data_of_cars
# Out:
#      Unnamed: 0.1  Unnamed: 0                               Name Location  \
# 0               1           2                       Honda Jazz V  Chennai
# 1               5           7  Toyota Innova Crysta 2.8 GX AT 8S   Mumbai
# 2               8          10                   Maruti Ciaz Zeta    Kochi
# 3              13          15        Mitsubishi Pajero Sport 4X4    Delhi
# 4              18          20                  BMW 3 Series 320d    Kochi
# ..            ...         ...                                ...      ...
# 809          5827        5999              Tata Bolt Revotron XT  Chennai
# 810          5830        6002      Volkswagen Vento 1.6 Highline   Mumbai
# 811          5833        6005           Maruti Vitara Brezza VDi     Pune
# 812          5838        6010               Honda Brio 1.2 VX MT    Delhi
# 813          5842        6014                   Maruti Swift VDI    Delhi
#
#      Year  Kilometers_Driven Owner_Type  Mileage  Engine   Power  Seats  \
# ...
